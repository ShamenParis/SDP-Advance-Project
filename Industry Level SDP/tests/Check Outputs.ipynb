-- %%
-- DROP TABLE ath_catalog.raw.customers;
-- DROP TABLE ath_catalog.raw.orders;
-- DROP TABLE ath_catalog.raw.product_category;
-- DROP TABLE ath_catalog.raw.products;
-- DROP TABLE ath_catalog.raw.sales;
-- DROP TABLE ath_catalog.raw.warehouse;

-- %%
-- DROP TABLE ath_catalog.clean.customers;
-- DROP TABLE ath_catalog.clean.orders;
-- DROP TABLE ath_catalog.clean.products_scd;
-- DROP TABLE ath_catalog.clean.products;
-- DROP TABLE ath_catalog.clean.sales;
-- DROP TABLE ath_catalog.clean.warehouse;

-- %% [markdown]
-- # customers

-- %%
SELECT * FROM ath_catalog.raw.customers

-- %%
SELECT * FROM ath_catalog.clean.customers

-- %%
SELECT * FROM ath_catalog.raw.orders

-- %%
SELECT * FROM ath_catalog.clean.orders
